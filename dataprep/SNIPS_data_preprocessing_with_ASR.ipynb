# %% [markdown]
# ### Read data

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
snips = pd.read_csv('complete.csv')
asr = pd.read_csv('snips_ASRcomplete.csv', index_col=0)

# %%
snips.head()
# Out:
#                                                 path  \
# 0  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1  /snips/wavs/snips_real/smart-lights-en-close-f...
# 2  /snips/wavs/snips_real/smart-lights-en-close-f...
# 3  /snips/wavs/snips_real/smart-lights-en-close-f...
# 4  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                        transcription  \
# 0       Activate all the lights in the entire house.
# 1                           Activate basement lights
# 2  Adjust the bedroom light intensity to thirty nine
# 3      Can you please change the light color to pink
# 4                        Set the brightness to five.
#
#                                            semantics
# 0  {'intent': 'SwitchLightOn', 'slots': [{'entity...
# 1  {'intent': 'SwitchLightOn', 'slots': [{'entity...
# 2  {'intent': 'SetLightBrightness', 'slots': [{'e...
# 3  {'intent': 'SetLightColor', 'slots': [{'entity...
# 4  {'intent': 'SetLightBrightness', 'slots': [{'e...

# %%
asr.head()
# Out:
#                                       asr_transcript         uniqueId
# 0             Activate all life and needs her house   sample0000-0000
# 1                          Activate basement lights   sample0001-0001
# 2  I just the beggar blight intensity a thirty nine   sample0002-0010
# 3  Can you please changed the light coloured to t...  sample0003-0100
# 4                          Said the mate mystifying   sample0004-1000

# %% [markdown]
# ### Merge GT and ASR data

# %%
snips = snips.reset_index()
snips['speakerId'] = snips['index'].apply(lambda x: '{0:04}'.format(x))
snips['speakerId'] = snips['speakerId'].apply(lambda x: 'sample'+str(x))
snips['sampleId'] = snips['path'].apply(lambda x: int(x.split("/")[-1].split(".")[0]))
snips['sampleId'] = snips['sampleId'].apply(lambda x: '{0:04}'.format(x))
snips['uniqueId'] = snips[['speakerId', 'sampleId']].agg('-'.join, axis=1)
snips = snips.drop(columns='index')

snips_asr = pd.merge(snips,asr,on='uniqueId')
snips_asr
# Out:
#                                                    path  \
# 0     /snips/wavs/snips_real/smart-lights-en-close-f...
# 1     /snips/wavs/snips_real/smart-lights-en-close-f...
# 2     /snips/wavs/snips_real/smart-lights-en-close-f...
# 3     /snips/wavs/snips_real/smart-lights-en-close-f...
# 4     /snips/wavs/snips_real/smart-lights-en-close-f...
# ...                                                 ...
# 1655  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1656  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1657  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1658  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1659  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                           transcription  \
# 0          Activate all the lights in the entire house.
# 1                              Activate basement lights
# 2     Adjust the bedroom light intensity to thirty nine
# 3         Can you please change the light color to pink
# 4                           Set the brightness to five.
# ...                                                 ...
# 1655        Set the brightness level of light to twenty
# 1656          Set the brightness level to seventy-three
# 1657   Set the brightness of the light bulbs to fifty.
# 1658    Set the brightness on the light bulbs to fifty.
# 1659                       Set the brightness to fifty.
#
#                                               semantics   speakerId sampleId  \
# 0     {'intent': 'SwitchLightOn', 'slots': [{'entity...  sample0000     0000
# 1     {'intent': 'SwitchLightOn', 'slots': [{'entity...  sample0001     0001
# 2     {'intent': 'SetLightBrightness', 'slots': [{'e...  sample0002     0010
# 3     {'intent': 'SetLightColor', 'slots': [{'entity...  sample0003     0100
# 4     {'intent': 'SetLightBrightness', 'slots': [{'e...  sample0004     1000
# ...                                                 ...         ...      ...
# 1655  {'intent': 'SetLightBrightness', 'slots': [{'e...  sample1655     0995
# 1656  {'intent': 'SetLightBrightness', 'slots': [{'e...  sample1656     0996
# 1657  {'intent': 'SetLightBrightness', 'slots': [{'e...  sample1657     0997
# 1658  {'intent': 'SetLightBrightness', 'slots': [{'e...  sample1658     0998
# 1659  {'intent': 'SetLightBrightness', 'slots': [{'e...  sample1659     0999
#
#              uniqueId                                     asr_transcript
# 0     sample0000-0000             Activate all life and needs her house
# 1     sample0001-0001                          Activate basement lights
# 2     sample0002-0010  I just the beggar blight intensity a thirty nine
# 3     sample0003-0100  Can you please changed the light coloured to t...
# 4     sample0004-1000                          Said the mate mystifying
# ...               ...                                                ...
# 1655  sample1655-0995       Set the brightness level of white to twenty
# 1656  sample1656-0996      Said the brightness lovell two seventy three
# 1657  sample1657-0997   Said the brightness of the light bulbs to fifty
# 1658  sample1658-0998   Said the brightness of the light bulbs to fifty
# 1659  sample1659-0999                          Separate not stupid dean
#
# [1660 rows x 7 columns]

# %% [markdown]
# ### Split into train/valid/test (80/10/10)

# %%
intent_text_list = [semantics[12:].split("'")[0] for semantics in snips_asr['semantics']] #"SwitchLightOn"

snips_asr['intent'] = intent_text_list

train, valtest = train_test_split(snips_asr, test_size=0.2, random_state=42)
valid, test = train_test_split(valtest, test_size=0.5, random_state=42)

# %%
len(train), len(valid), len(test)
# Out:
# (1328, 166, 166)

# %% [markdown]
# ### Save the original (this dataset serves as gt_gt)

# %%
train[['path','transcription','asr_transcript','semantics', 'intent']].to_csv('train_data.csv')
valid[['path','transcription','asr_transcript','semantics', 'intent']].to_csv('valid_data.csv')
test[['path','transcription','asr_transcript','semantics', 'intent']].to_csv('test_data.csv')

# %% [markdown]
# ### Merge the ground truth and asr transcripts into ONE column

# %%
train_raw = pd.read_csv("train_data.csv", index_col=0)
train_asr = pd.read_csv("train_data.csv", index_col=0)

valid_raw = pd.read_csv("valid_data.csv", index_col=0)
valid_asr = pd.read_csv("valid_data.csv", index_col=0)

test_raw = pd.read_csv("test_data.csv", index_col=0)
test_asr = pd.read_csv("test_data.csv", index_col=0)

# %%
train_raw['type'] = 'raw'
train_raw = train_raw.drop(columns=['asr_transcript'])
train_asr['type'] = 'asr'
train_asr = train_asr.drop(columns=['transcription'])
train_asr.columns = ['path', 'transcription', 'semantics', 'intent', 'type']

# %%
display(train_raw.head(5))
display(train_asr.head(5))
# Out:
#                                                   path  \
# 266  /snips/wavs/snips_real/smart-lights-en-close-f...
# 148  /snips/wavs/snips_real/smart-lights-en-close-f...
# 567  /snips/wavs/snips_real/smart-lights-en-close-f...
# 744  /snips/wavs/snips_real/smart-lights-en-close-f...
# 588  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                          transcription  \
# 266            Turn the bedroom light to seventy-three
# 148                   Turn brightness down in bed room
# 567                       make the living room lighter
# 744  Change the color of the lights to blue in the ...
# 588                          please give me some light
#
#                                              semantics              intent  \
# 266  {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 148  {'intent': 'DecreaseBrightness', 'slots': [{'e...  DecreaseBrightness
# 567  {'intent': 'IncreaseBrightness', 'slots': [{'e...  IncreaseBrightness
# 744  {'intent': 'SetLightColor', 'slots': [{'entity...       SetLightColor
# 588           {'intent': 'SwitchLightOn', 'slots': []}       SwitchLightOn
#
#     type
# 266  raw
# 148  raw
# 567  raw
# 744  raw
# 588  raw
#                                                   path  \
# 266  /snips/wavs/snips_real/smart-lights-en-close-f...
# 148  /snips/wavs/snips_real/smart-lights-en-close-f...
# 567  /snips/wavs/snips_real/smart-lights-en-close-f...
# 744  /snips/wavs/snips_real/smart-lights-en-close-f...
# 588  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                          transcription  \
# 266         During the bedroom light he seventy three
# 148                  Turn brightness down and bedroom
# 567                      Make the living room lighter
# 744  Change the colour of the lights to blue and th...
# 588                         Please give me some light
#
#                                              semantics              intent  \
# 266  {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 148  {'intent': 'DecreaseBrightness', 'slots': [{'e...  DecreaseBrightness
# 567  {'intent': 'IncreaseBrightness', 'slots': [{'e...  IncreaseBrightness
# 744  {'intent': 'SetLightColor', 'slots': [{'entity...       SetLightColor
# 588           {'intent': 'SwitchLightOn', 'slots': []}       SwitchLightOn
#
#     type
# 266  asr
# 148  asr
# 567  asr
# 744  asr
# 588  asr

# %%
valid_raw['type'] = 'raw'
valid_raw = valid_raw.drop(columns=['asr_transcript'])
valid_asr['type'] = 'asr'
valid_asr = valid_asr.drop(columns=['transcription'])
valid_asr.columns = ['path', 'transcription', 'semantics', 'intent', 'type']

# %%
display(valid_raw.head(5))
display(valid_asr.head(5))
# Out:
#                                                    path  \
# 664   /snips/wavs/snips_real/smart-lights-en-close-f...
# 361   /snips/wavs/snips_real/smart-lights-en-close-f...
# 1615  /snips/wavs/snips_real/smart-lights-en-close-f...
# 366   /snips/wavs/snips_real/smart-lights-en-close-f...
# 1247  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                 transcription  \
# 664     Adjust the cella lights to twenty two
# 361   Turn the waiting room brightness to two
# 1615                        Put the lights on
# 366                      Turn up the lighting
# 1247                Kill the bathroom lights.
#
#                                               semantics              intent  \
# 664   {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 361   {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 1615           {'intent': 'SwitchLightOn', 'slots': []}       SwitchLightOn
# 366       {'intent': 'IncreaseBrightness', 'slots': []}  IncreaseBrightness
# 1247  {'intent': 'SwitchLightOff', 'slots': [{'entit...      SwitchLightOff
#
#      type
# 664   raw
# 361   raw
# 1615  raw
# 366   raw
# 1247  raw
#                                                    path  \
# 664   /snips/wavs/snips_real/smart-lights-en-close-f...
# 361   /snips/wavs/snips_real/smart-lights-en-close-f...
# 1615  /snips/wavs/snips_real/smart-lights-en-close-f...
# 366   /snips/wavs/snips_real/smart-lights-en-close-f...
# 1247  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                     transcription  \
# 664          I just the saw lights to twenty two
# 361   Turn on the waiting room brightness to too
# 1615                           Put the lights on
# 366                         Turn up the lighting
# 1247                    Kill the bathroom lights
#
#                                               semantics              intent  \
# 664   {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 361   {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 1615           {'intent': 'SwitchLightOn', 'slots': []}       SwitchLightOn
# 366       {'intent': 'IncreaseBrightness', 'slots': []}  IncreaseBrightness
# 1247  {'intent': 'SwitchLightOff', 'slots': [{'entit...      SwitchLightOff
#
#      type
# 664   asr
# 361   asr
# 1615  asr
# 366   asr
# 1247  asr

# %%
test_raw['type'] = 'raw'
test_raw = test_raw.drop(columns=['asr_transcript'])
test_asr['type'] = 'asr'
test_asr = test_asr.drop(columns=['transcription'])
test_asr.columns = ['path', 'transcription', 'semantics', 'intent', 'type']

# %%
display(test_raw.head(5))
display(test_asr.head(5))
# Out:
#                                                    path  \
# 1445  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1368  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1093  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1516  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1253  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                        transcription  \
# 1445                               More light please
# 1368  Make the kids bedroom brighter with more light
# 1093              I want to turn off the patio lamps
# 1516             Can you make the brightness twelve?
# 1253                              Let there be light
#
#                                               semantics              intent  \
# 1445      {'intent': 'IncreaseBrightness', 'slots': []}  IncreaseBrightness
# 1368  {'intent': 'IncreaseBrightness', 'slots': [{'e...  IncreaseBrightness
# 1093  {'intent': 'SwitchLightOff', 'slots': [{'entit...      SwitchLightOff
# 1516  {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 1253           {'intent': 'SwitchLightOn', 'slots': []}       SwitchLightOn
#
#      type
# 1445  raw
# 1368  raw
# 1093  raw
# 1516  raw
# 1253  raw
#                                                    path  \
# 1445  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1368  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1093  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1516  /snips/wavs/snips_real/smart-lights-en-close-f...
# 1253  /snips/wavs/snips_real/smart-lights-en-close-f...
#
#                                          transcription  \
# 1445                                More light please
# 1368  Make the keats bedroom brighter with more light
# 1093                I want to turn off the patio laps
# 1516               Can you make the brightness twelve
# 1253                                 Let there be lie
#
#                                               semantics              intent  \
# 1445      {'intent': 'IncreaseBrightness', 'slots': []}  IncreaseBrightness
# 1368  {'intent': 'IncreaseBrightness', 'slots': [{'e...  IncreaseBrightness
# 1093  {'intent': 'SwitchLightOff', 'slots': [{'entit...      SwitchLightOff
# 1516  {'intent': 'SetLightBrightness', 'slots': [{'e...  SetLightBrightness
# 1253           {'intent': 'SwitchLightOn', 'slots': []}       SwitchLightOn
#
#      type
# 1445  asr
# 1368  asr
# 1093  asr
# 1516  asr
# 1253  asr

# %%
train_combined = pd.concat([train_raw, train_asr])
valid_combined = pd.concat([valid_raw, valid_asr])
test_combined = pd.concat([test_raw, test_asr])

# %%
len(train_combined), len(valid_combined), len(test_combined)
# Out:
# (2656, 332, 332)

# %%
len(train_raw), len(valid_raw), len(test_raw)
# Out:
# (1328, 166, 166)

# %%
train_combined_sh = shuffle(train_combined, random_state=42)
valid_combined_sh = shuffle(valid_combined, random_state=42)
test_combined_sh = shuffle(test_combined, random_state=42)

# %% [markdown]
# ### Save gt_asr

# %%
# train_raw[['path','transcription','semantics', 'intent', 'type']].to_csv('train_data.csv')
# valid_raw[['path','transcription','semantics', 'intent', 'type']].to_csv('valid_data.csv')
# test_asr[['path','transcription','semantics', 'intent', 'type']].to_csv('test_data.csv')

# %% [markdown]
# ### Save gtasr_gt

# %%
# train_combined_sh[['path','transcription','semantics', 'intent', 'type']].to_csv('train_data.csv')
# valid_combined_sh[['path','transcription','semantics', 'intent', 'type']].to_csv('valid_data.csv')
# test_raw[['path','transcription','semantics', 'intent', 'type']].to_csv('test_data.csv')

# %% [markdown]
# ### Save gtasr_asr

# %%
# train_combined_sh[['path','transcription','semantics', 'intent', 'type']].to_csv('train_data.csv')
# valid_combined_sh[['path','transcription','semantics', 'intent', 'type']].to_csv('valid_data.csv')
# test_asr[['path','transcription','semantics', 'intent', 'type']].to_csv('test_data.csv')

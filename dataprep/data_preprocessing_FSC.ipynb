# %% [markdown]
# ### Read data

# %%
import pandas as pd
from sklearn.utils import shuffle

# %%
train = pd.read_csv('train_data.csv')
valid = pd.read_csv('valid_data.csv')
test = pd.read_csv('test_data.csv')

# %%
train_asr = pd.read_csv('fluentai_ASRtrain.csv', index_col=0)
valid_asr = pd.read_csv('fluentai_ASRvalid.csv', index_col=0)
test_asr = pd.read_csv('fluentai_ASRtest.csv', index_col=0)

# %%
train.head()
# Out:
#                                                 path         speakerId  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 1  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 2  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 3  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 4  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
#
#            transcription           action  object location  \
# 0        Change language  change language    none     none
# 1                 Resume         activate   music     none
# 2     Turn the lights on         activate  lights     none
# 3   Switch on the lights         activate  lights     none
# 4  Switch off the lights       deactivate  lights     none
#
#                            sampleId  \
# 0  0a3129c0447411e9a9a55dbec3b8816a
# 1  0ee42a80447411e9a9a55dbec3b8816a
# 2  144d5be0447411e9a9a55dbec3b8816a
# 3  1811b6e0447411e9a9a55dbec3b8816a
# 4  1d9f3920447411e9a9a55dbec3b8816a
#
#                                             uniqueId
# 0  2BqVo8kVB2Skwgyb-0a3129c0447411e9a9a55dbec3b8816a
# 1  2BqVo8kVB2Skwgyb-0ee42a80447411e9a9a55dbec3b8816a
# 2  2BqVo8kVB2Skwgyb-144d5be0447411e9a9a55dbec3b8816a
# 3  2BqVo8kVB2Skwgyb-1811b6e0447411e9a9a55dbec3b8816a
# 4  2BqVo8kVB2Skwgyb-1d9f3920447411e9a9a55dbec3b8816a

# %%
train_asr.head()
# Out:
#                               asr_transcript  \
# 0  In gran'ther he'd being in their barbran
# 1                     It's than life all eh
# 2              Dawn that bedroom life often
# 3                              Length heath
# 4     Then they he'd up in the logs shortly
#
#                                             uniqueId
# 0  2BqVo8kVB2Skwgyb-029f6450447a11e9a9a55dbec3b8816a
# 1  2BqVo8kVB2Skwgyb-03592c80447c11e9a9a55dbec3b8816a
# 2  2BqVo8kVB2Skwgyb-063aa8f0447911e9a9a55dbec3b8816a
# 3  2BqVo8kVB2Skwgyb-07858300447a11e9a9a55dbec3b8816a
# 4  2BqVo8kVB2Skwgyb-0887f780447d11e9a9a55dbec3b8816a

# %% [markdown]
# ### Merge GT and ASR data

# %%
train['sampleId'] = train['path'].apply(lambda x: x.split("/")[-1].split(".")[0].replace("-",""))
valid['sampleId'] = valid['path'].apply(lambda x: x.split("/")[-1].split(".")[0].replace("-",""))
test['sampleId'] = test['path'].apply(lambda x: x.split("/")[-1].split(".")[0].replace("-",""))

train['uniqueId'] = train[['speakerId', 'sampleId']].agg('-'.join, axis=1)
valid['uniqueId'] = valid[['speakerId', 'sampleId']].agg('-'.join, axis=1)
test['uniqueId'] = test[['speakerId', 'sampleId']].agg('-'.join, axis=1)

train_gt_asr = pd.merge(train, train_asr, on='uniqueId')
valid_gt_asr = pd.merge(valid, valid_asr, on='uniqueId')
test_gt_asr = pd.merge(test, test_asr, on='uniqueId')

# %%
train_gt_asr.head()
# Out:
#                                                 path         speakerId  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 1  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 2  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 3  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
# 4  /fluent_speech_commands_dataset/wavs/speakers/...  2BqVo8kVB2Skwgyb
#
#            transcription           action  object location  \
# 0        Change language  change language    none     none
# 1                 Resume         activate   music     none
# 2     Turn the lights on         activate  lights     none
# 3   Switch on the lights         activate  lights     none
# 4  Switch off the lights       deactivate  lights     none
#
#                            sampleId  \
# 0  0a3129c0447411e9a9a55dbec3b8816a
# 1  0ee42a80447411e9a9a55dbec3b8816a
# 2  144d5be0447411e9a9a55dbec3b8816a
# 3  1811b6e0447411e9a9a55dbec3b8816a
# 4  1d9f3920447411e9a9a55dbec3b8816a
#
#                                             uniqueId        asr_transcript
# 0  2BqVo8kVB2Skwgyb-0a3129c0447411e9a9a55dbec3b8816a      Change languish
# 1  2BqVo8kVB2Skwgyb-0ee42a80447411e9a9a55dbec3b8816a               Assume
# 2  2BqVo8kVB2Skwgyb-144d5be0447411e9a9a55dbec3b8816a    Don the lights on
# 3  2BqVo8kVB2Skwgyb-1811b6e0447411e9a9a55dbec3b8816a      On the lay this
# 4  2BqVo8kVB2Skwgyb-1d9f3920447411e9a9a55dbec3b8816a  This off the lights

# %% [markdown]
# ### Save the original (this dataset serves as gt_gt)

# %%
train_gt_asr[['path','transcription','asr_transcript','action','object','location']].to_csv('train_data.csv')
valid_gt_asr[['path','transcription','asr_transcript','action','object','location']].to_csv('valid_data.csv')
test_gt_asr[['path','transcription','asr_transcript','action','object','location']].to_csv('test_data.csv')

# %% [markdown]
# ### Merge the ground truth and asr transcripts into ONE column

# %%
train_raw = pd.read_csv("train_data.csv", index_col=0)
train_asr = pd.read_csv("train_data.csv", index_col=0)

valid_raw = pd.read_csv("valid_data.csv", index_col=0)
valid_asr = pd.read_csv("valid_data.csv", index_col=0)

test_raw = pd.read_csv("test_data.csv", index_col=0)
test_asr = pd.read_csv("test_data.csv", index_col=0)

# %%
train_raw['type'] = 'raw'
train_raw = train_raw.drop(columns=['asr_transcript'])
train_asr['type'] = 'asr'
train_asr = train_asr.drop(columns=['transcription'])
train_asr.columns = ['path', 'transcription', 'action', 'object', 'location', 'type']

# %%
display(train_raw.head(5))
display(train_asr.head(5))
# Out:
#                                                 path          transcription  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...        Change language
# 1  /fluent_speech_commands_dataset/wavs/speakers/...                 Resume
# 2  /fluent_speech_commands_dataset/wavs/speakers/...     Turn the lights on
# 3  /fluent_speech_commands_dataset/wavs/speakers/...   Switch on the lights
# 4  /fluent_speech_commands_dataset/wavs/speakers/...  Switch off the lights
#
#             action  object location type
# 0  change language    none     none  raw
# 1         activate   music     none  raw
# 2         activate  lights     none  raw
# 3         activate  lights     none  raw
# 4       deactivate  lights     none  raw
#                                                 path         transcription  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...      Change languish
# 1  /fluent_speech_commands_dataset/wavs/speakers/...               Assume
# 2  /fluent_speech_commands_dataset/wavs/speakers/...    Don the lights on
# 3  /fluent_speech_commands_dataset/wavs/speakers/...      On the lay this
# 4  /fluent_speech_commands_dataset/wavs/speakers/...  This off the lights
#
#             action  object location type
# 0  change language    none     none  asr
# 1         activate   music     none  asr
# 2         activate  lights     none  asr
# 3         activate  lights     none  asr
# 4       deactivate  lights     none  asr

# %%
valid_raw['type'] = 'raw'
valid_raw = valid_raw.drop(columns=['asr_transcript'])
valid_asr['type'] = 'asr'
valid_asr = valid_asr.drop(columns=['transcription'])
valid_asr.columns = ['path', 'transcription', 'action', 'object', 'location', 'type']

# %%
display(valid_raw.head(5))
display(valid_asr.head(5))
# Out:
#                                                 path        transcription  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...   Turn on the lights
# 1  /fluent_speech_commands_dataset/wavs/speakers/...  Turn off the lights
# 2  /fluent_speech_commands_dataset/wavs/speakers/...      Change language
# 3  /fluent_speech_commands_dataset/wavs/speakers/...      Pause the music
# 4  /fluent_speech_commands_dataset/wavs/speakers/...               Resume
#
#             action  object location type
# 0         activate  lights     none  raw
# 1       deactivate  lights     none  raw
# 2  change language    none     none  raw
# 3       deactivate   music     none  raw
# 4         activate   music     none  raw
#                                                 path         transcription  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...   Turn on the lights
# 1  /fluent_speech_commands_dataset/wavs/speakers/...  Turn off the lights
# 2  /fluent_speech_commands_dataset/wavs/speakers/...      Change language
# 3  /fluent_speech_commands_dataset/wavs/speakers/...     Caused the music
# 4  /fluent_speech_commands_dataset/wavs/speakers/...              Resumed
#
#             action  object location type
# 0         activate  lights     none  asr
# 1       deactivate  lights     none  asr
# 2  change language    none     none  asr
# 3       deactivate   music     none  asr
# 4         activate   music     none  asr

# %%
test_raw['type'] = 'raw'
test_raw = test_raw.drop(columns=['asr_transcript'])
test_asr['type'] = 'asr'
test_asr = test_asr.drop(columns=['transcription'])
test_asr.columns = ['path', 'transcription', 'action', 'object', 'location', 'type']

# %%
display(test_raw.head(5))
display(test_asr.head(5))
# Out:
#                                                 path        transcription  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...   Turn on the lights
# 1  /fluent_speech_commands_dataset/wavs/speakers/...  Turn off the lights
# 2  /fluent_speech_commands_dataset/wavs/speakers/...      Change language
# 3  /fluent_speech_commands_dataset/wavs/speakers/...      Pause the music
# 4  /fluent_speech_commands_dataset/wavs/speakers/...               Resume
#
#             action  object location type
# 0         activate  lights     none  raw
# 1       deactivate  lights     none  raw
# 2  change language    none     none  raw
# 3       deactivate   music     none  raw
# 4         activate   music     none  raw
#                                                 path         transcription  \
# 0  /fluent_speech_commands_dataset/wavs/speakers/...   Turn on the lights
# 1  /fluent_speech_commands_dataset/wavs/speakers/...  Turn off the lights
# 2  /fluent_speech_commands_dataset/wavs/speakers/...      Change language
# 3  /fluent_speech_commands_dataset/wavs/speakers/...     Paused the music
# 4  /fluent_speech_commands_dataset/wavs/speakers/...              Resumed
#
#             action  object location type
# 0         activate  lights     none  asr
# 1       deactivate  lights     none  asr
# 2  change language    none     none  asr
# 3       deactivate   music     none  asr
# 4         activate   music     none  asr

# %%
train_combined = pd.concat([train_raw, train_asr])
valid_combined = pd.concat([valid_raw, valid_asr])
test_combined = pd.concat([test_raw, test_asr])

# %%
len(train_combined), len(valid_combined), len(test_combined)
# Out:
# (46264, 6236, 7586)

# %%
len(train_raw), len(valid_raw), len(test_raw)
# Out:
# (23132, 3118, 3793)

# %%
train_combined_sh = shuffle(train_combined, random_state=42)
valid_combined_sh = shuffle(valid_combined, random_state=42)
test_combined_sh = shuffle(test_combined, random_state=42)

# %% [markdown]
# ### Save gt_asr

# %%
# train_raw[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('train_data.csv')
# valid_raw[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('valid_data.csv')
# test_asr[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('test_data.csv')

# %% [markdown]
# ### Save gtasr_gt

# %%
# train_combined_sh[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('train_data.csv')
# valid_combined_sh[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('valid_data.csv')
# test_raw[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('test_data.csv')

# %% [markdown]
# ### Save gtasr_asr

# %%
# train_combined_sh[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('train_data.csv')
# valid_combined_sh[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('valid_data.csv')
# test_asr[['path', 'transcription', 'action', 'object', 'location', 'type']].to_csv('test_data.csv')

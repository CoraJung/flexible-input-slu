# %% [markdown]
# ### Read data

# %%
import pandas as pd

# %%
train = pd.read_csv('train_data.csv')
val = pd.read_csv('valid_data.csv')
test = pd.read_csv('test_data.csv')

# %%
train_asr = pd.read_csv('fluentai_ASRtrain.csv')
val_asr = pd.read_csv('fluentai_ASRvalid.csv')
test_asr = pd.read_csv('fluentai_ASRtest.csv')

# %% [markdown]
# ### Merge GT and ASR data

# %%
train['sampleId'] = fluent['path'].apply(lambda x: x.split("/")[-1].split(".")[0].replace("-",""))
val['sampleId'] = val['path'].apply(lambda x: x.split("/")[-1].split(".")[0].replace("-",""))
test['sampleId'] = test['path'].apply(lambda x: x.split("/")[-1].split(".")[0].replace("-",""))

train['uniqueId'] = fluent[['speakerId', 'sampleId']].agg('-'.join, axis=1)
val['uniqueId'] = val[['speakerId', 'sampleId']].agg('-'.join, axis=1)
test['uniqueId'] = test[['speakerId', 'sampleId']].agg('-'.join, axis=1)

train_gt_asr = pd.merge(train, train_asr,on='uniqueId')
valid_gt_asr = pd.merge(val,val_asr,on='uniqueId')
test_gt_asr = pd.merge(test,test_asr,on='uniqueId')

# %%
test_gt_asr
# Out:
#                                                    path         speakerId  \
# 0     /fluent_speech_commands_dataset/wavs/speakers/...  4BrX8aDqK2cLZRYl
# 1     /fluent_speech_commands_dataset/wavs/speakers/...  4BrX8aDqK2cLZRYl
# 2     /fluent_speech_commands_dataset/wavs/speakers/...  4BrX8aDqK2cLZRYl
# 3     /fluent_speech_commands_dataset/wavs/speakers/...  4BrX8aDqK2cLZRYl
# 4     /fluent_speech_commands_dataset/wavs/speakers/...  4BrX8aDqK2cLZRYl
# ...                                                 ...               ...
# 3788  /fluent_speech_commands_dataset/wavs/speakers/...  V4ZbwLm9G5irobWn
# 3789  /fluent_speech_commands_dataset/wavs/speakers/...  V4ZbwLm9G5irobWn
# 3790  /fluent_speech_commands_dataset/wavs/speakers/...  V4ZbwLm9G5irobWn
# 3791  /fluent_speech_commands_dataset/wavs/speakers/...  V4ZbwLm9G5irobWn
# 3792  /fluent_speech_commands_dataset/wavs/speakers/...  V4ZbwLm9G5irobWn
#
#                                           transcription           action  \
# ...

# %% [markdown]
# ### Save used columns to csv

# %%
train_gt_asr[['path','transcription','asr_transcript','action','object','location']].to_csv('train_data_gtasr.csv',index=False)
valid_gt_asr[['path','transcription','asr_transcript','action','object','location']].to_csv('valid_data_gtasr.csv',index=False)
test_gt_asr[['path','transcription','asr_transcript','action','object','location']].to_csv('test_data_gtasr.csv',index=False)
pd.read_csv('test_data_gtasr.csv')
# Out:
#                                                    path  \
# 0     /fluent_speech_commands_dataset/wavs/speakers/...
# 1     /fluent_speech_commands_dataset/wavs/speakers/...
# 2     /fluent_speech_commands_dataset/wavs/speakers/...
# 3     /fluent_speech_commands_dataset/wavs/speakers/...
# 4     /fluent_speech_commands_dataset/wavs/speakers/...
# ...                                                 ...
# 3788  /fluent_speech_commands_dataset/wavs/speakers/...
# 3789  /fluent_speech_commands_dataset/wavs/speakers/...
# 3790  /fluent_speech_commands_dataset/wavs/speakers/...
# 3791  /fluent_speech_commands_dataset/wavs/speakers/...
# 3792  /fluent_speech_commands_dataset/wavs/speakers/...
#
#                                           transcription  \
# 0                                    Turn on the lights
# 1                                   Turn off the lights
# 2                                       Change language
# 3                                       Pause the music
# ...
